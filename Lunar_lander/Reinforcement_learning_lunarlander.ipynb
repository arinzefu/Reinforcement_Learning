# %% [markdown]
# # Reinforcement learning on ai playing lunarlander

# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 24 not upgraded.
# Need to get 1,086 kB of archives.
# After this operation, 5,413 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig4.0 amd64 4.0.1-5build1 [1,081 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig all 4.0.1-5build1 [5,528 B]
# Fetched 1,086 kB in 1s (1,147 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 122349 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.1-5build1_amd64.deb ...
# Unpacking swig4.0 (4.0.1-5build1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.1-5build1_all.deb ...
# Unpacking swig (4.0.1-5build1) ...
# Setting up swig4.0 (4.0.1-5build1) ...
# Setting up swig (4.0.1-5build1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !pip install setuptools==65.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setuptools==65.5.0
#   Downloading setuptools-65.5.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.7 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.6.1
#     Uninstalling setuptools-67.6.1:
#       Successfully uninstalled setuptools-67.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# cvxpy 1.3.1 requires setuptools>65.5.1, but you have setuptools 65.5.0 which is incompatible.
# Successfully installed setuptools-65.5.0

# %%
# !pip install stable-baselines3[extra]
# !pip install box2d-py
# !pip install huggingface_sb3
# !pip install pyglet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-1.8.0-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (1.5.3)
# Collecting importlib-metadata~=4.13
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (3.7.1)
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (2.0.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (1.22.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (13.3.3)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (2.12.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (8.4.0)
# Collecting autorom[accept-rom-license]~=0.6.0
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (5.9.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (4.65.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from stable-baselines3[extra]) (4.7.0.72)
# Collecting ale-py==0.7.4
#   Downloading ale_py-0.7.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.9/dist-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.1.3)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 37.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.15.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.5.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.17.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.53.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.40.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3[extra]) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.11.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (3.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable-baselines3[extra]) (4.39.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->stable-baselines3[extra]) (2022.7.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.0.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Building wheels for collected packages: gym, AutoROM.accept-rom-license
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for gym (setup.py) ... error
#   ERROR: Failed building wheel for gym
#   Running setup.py clean for gym
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446676 sha256=08ad02635eaa4caea2bf76a5385714682cff0066978299b46381c957b50d5dae
#   Stored in directory: /root/.cache/pip/wheels/b1/1f/f7/2da07cf4f81ea264bdaf043028749d88fe0c2227134a22cf80
# Successfully built AutoROM.accept-rom-license
# Failed to build gym
# Installing collected packages: importlib-metadata, gym, AutoROM.accept-rom-license, autorom, ale-py, stable-baselines3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.2.0
#     Uninstalling importlib-metadata-6.2.0:
#       Successfully uninstalled importlib-metadata-6.2.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Running setup.py install for gym ... done
#   DEPRECATION: gym was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. pip 23.1 will enforce this behaviour change. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.7.4 autorom-0.6.1 gym-0.21.0 importlib-metadata-4.13.0 stable-baselines3-1.8.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp39-cp39-linux_x86_64.whl size=2778355 sha256=b0be5ca7c786cf633ede5741b40e4b544e8e9d6562e5cea652b05afb39171068
#   Stored in directory: /root/.cache/pip/wheels/a0/6a/54/2383a12859109612796c6b235ff6704a82b99caa4308ca0b43
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting huggingface_sb3
#   Downloading huggingface_sb3-2.2.4-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.9/dist-packages (from huggingface_sb3) (6.0)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.9/dist-packages (from huggingface_sb3) (1.1.1)
# Collecting huggingface-hub~=0.8
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from huggingface_sb3) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.9/dist-packages (from huggingface_sb3) (2.2.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (23.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.0.12)
# Installing collected packages: huggingface-hub, huggingface_sb3
# Successfully installed huggingface-hub-0.13.4 huggingface_sb3-2.2.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyglet
#   Downloading pyglet-2.0.5-py3-none-any.whl (831 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.3/831.3 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: pyglet
# Successfully installed pyglet-2.0.5

# %%
# !sudo apt-get update
# !pip install gym
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:11 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,593 kB]
# Hit:12 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,075 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,028 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,324 kB]
# Fetched 8,360 kB in 2s (3,676 kB/s)
# Reading package lists... Done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym in /usr/local/lib/python3.9/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.9/dist-packages (from gym) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gym) (2.2.1)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   freeglut3 libpython2-stdlib python2 python2-minimal
# Suggested packages:
#   python-tk python-numpy libgle3 python2-doc
# The following NEW packages will be installed:
#   freeglut3 libpython2-stdlib python-opengl python2 python2-minimal
# 0 upgraded, 5 newly installed, 0 to remove and 31 not upgraded.
# Need to get 621 kB of archives.
# After this operation, 6,059 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-opengl all 3.1.0+dfsg-2build1 [486 kB]
# Fetched 621 kB in 1s (772 kB/s)
# Selecting previously unselected package python2-minimal.
# (Reading database ... 123100 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 123129 files and directories currently installed.)
# Preparing to unpack .../python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../python-opengl_3.1.0+dfsg-2build1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-2build1) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up python-opengl (3.1.0+dfsg-2build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 31 not upgraded.
# Need to get 7,697 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu1 [573 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.8 [27.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.8 [780 kB]
# Fetched 7,697 kB in 1s (7,059 kB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 125519 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu1_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a1.20.13-1ubuntu1~20.04.8_all.deb ...
# Unpacking xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a1.20.13-1ubuntu1~20.04.8_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up x11-xkb-utils (7.7+5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gym
from huggingface_sb3 import load_from_hub, package_to_hub, push_to_hub
from huggingface_hub import notebook_login
from collections import deque
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
env  = gym.make("LunarLander-v2")
#reset this environment
obseravation = env.reset()

for _ in range(10):
    #take random action
    action = env.action_space.sample()
    print("Action taken:", action)

    obseravation, reward, done, info = env.step(action)

    #if the game is done
    if done:
        #Reset the environment
        obseravation= env.reset()
        print("environment reset")
# Out:
# Action taken: 3
# Action taken: 0
# Action taken: 3
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 0
# Action taken: 1
# Action taken: 2
# Action taken: 2

# %%
env = make_vec_env("LunarLander-v2", n_envs = 8)

# %%
# Create environment
env = gym.make('LunarLander-v2')

model = PPO(
    policy="MlpPolicy",
    env=env,
    learning_rate=0.0001,  # lower learning rate for stability
    n_steps=2048,  # increase n_steps for more efficient training
    batch_size=64,  # increase batch size for more efficient training
    n_epochs=100,
    gamma=0.99,  # adjust gamma to balance immediate vs future rewards
    gae_lambda=0.96,  # adjust lambda to balance bias vs variance in advantage estimation
    clip_range=0.2,  # adjust clip range for policy gradient optimization
    clip_range_vf=None,  # disable clipping for value function optimization
    ent_coef=0.0,  # adjust entropy coefficient to balance exploration vs exploitation
    vf_coef=0.5,  # adjust value function coefficient to balance policy gradient and value function optimization
    max_grad_norm=0.7,  # setting gradient clipping
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
print(model)
# Out:
# <stable_baselines3.ppo.ppo.PPO object at 0x7fe7e1824040>

# %%
policy_net = model.policy
print(policy_net.parameters())
# Out:
# <generator object Module.parameters at 0x7fe7e18bc350>

# %%
import time

# %%
# Train the agent for 1000000 timesteps
start = time.time()
model.learn(total_timesteps=1000000)
end = time.time()

# Print the total training time
print(f"Total training time: {end - start:.2f} seconds")
# Out:
# Streaming output truncated to the last 5000 lines.
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 252         |
# |    time_elapsed         | 5149        |
# |    total_timesteps      | 516096      |
# | train/                  |             |
# |    approx_kl            | 0.005811212 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.51        |
# |    n_updates            | 25100       |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 26.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 253         |
# |    time_elapsed         | 5169        |
# |    total_timesteps      | 518144      |
# | train/                  |             |
# |    approx_kl            | 0.014730241 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.43        |
# |    n_updates            | 25200       |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 301         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 254         |
# |    time_elapsed         | 5189        |
# |    total_timesteps      | 520192      |
# | train/                  |             |
# |    approx_kl            | 0.008890478 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.413      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.37        |
# |    n_updates            | 25300       |
# |    policy_gradient_loss | -0.00656    |
# |    value_loss           | 6.61        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 308          |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 255          |
# |    time_elapsed         | 5209         |
# |    total_timesteps      | 522240       |
# | train/                  |              |
# |    approx_kl            | 0.0062600872 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.389       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.99         |
# |    n_updates            | 25400        |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 8.63         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 256         |
# |    time_elapsed         | 5230        |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.010517367 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.77        |
# |    n_updates            | 25500       |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 6.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 257         |
# |    time_elapsed         | 5249        |
# |    total_timesteps      | 526336      |
# | train/                  |             |
# |    approx_kl            | 0.040172406 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.284      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.4        |
# |    n_updates            | 25600       |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 64.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 325         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 258         |
# |    time_elapsed         | 5270        |
# |    total_timesteps      | 528384      |
# | train/                  |             |
# |    approx_kl            | 0.010060171 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.38       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.21        |
# |    n_updates            | 25700       |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 10.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 310        |
# |    ep_rew_mean          | 252        |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 259        |
# |    time_elapsed         | 5291       |
# |    total_timesteps      | 530432     |
# | train/                  |            |
# |    approx_kl            | 0.02615565 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.593     |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.78       |
# |    n_updates            | 25800      |
# |    policy_gradient_loss | -0.0146    |
# |    value_loss           | 8.25       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 320         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 260         |
# |    time_elapsed         | 5311        |
# |    total_timesteps      | 532480      |
# | train/                  |             |
# |    approx_kl            | 0.009558281 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.315      |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.53        |
# |    n_updates            | 25900       |
# |    policy_gradient_loss | -0.00847    |
# |    value_loss           | 67.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 321         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 261         |
# |    time_elapsed         | 5331        |
# |    total_timesteps      | 534528      |
# | train/                  |             |
# |    approx_kl            | 0.004280649 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.277      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.56        |
# |    n_updates            | 26000       |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 22.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 329         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 262         |
# |    time_elapsed         | 5351        |
# |    total_timesteps      | 536576      |
# | train/                  |             |
# |    approx_kl            | 0.006712875 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.312      |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.02        |
# |    n_updates            | 26100       |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 19.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 325        |
# |    ep_rew_mean          | 249        |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 263        |
# |    time_elapsed         | 5372       |
# |    total_timesteps      | 538624     |
# | train/                  |            |
# |    approx_kl            | 0.02518941 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.415     |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 4.32       |
# |    n_updates            | 26200      |
# |    policy_gradient_loss | -0.00903   |
# |    value_loss           | 13.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 264          |
# |    time_elapsed         | 5392         |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0029907082 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.304       |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.92         |
# |    n_updates            | 26300        |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 23.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 265          |
# |    time_elapsed         | 5412         |
# |    total_timesteps      | 542720       |
# | train/                  |              |
# |    approx_kl            | 0.0045863516 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.341       |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.98         |
# |    n_updates            | 26400        |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 26.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 309        |
# |    ep_rew_mean          | 252        |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 266        |
# |    time_elapsed         | 5434       |
# |    total_timesteps      | 544768     |
# | train/                  |            |
# |    approx_kl            | 0.01924771 |
# |    clip_fraction        | 0.0901     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.354     |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.52       |
# |    n_updates            | 26500      |
# |    policy_gradient_loss | -0.0113    |
# |    value_loss           | 9.64       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 314          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 267          |
# |    time_elapsed         | 5453         |
# |    total_timesteps      | 546816       |
# | train/                  |              |
# |    approx_kl            | 0.0036772252 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.318       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.33         |
# |    n_updates            | 26600        |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 7.13         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 314         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 268         |
# |    time_elapsed         | 5472        |
# |    total_timesteps      | 548864      |
# | train/                  |             |
# |    approx_kl            | 0.012529647 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39.4        |
# |    n_updates            | 26700       |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 28.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 269          |
# |    time_elapsed         | 5492         |
# |    total_timesteps      | 550912       |
# | train/                  |              |
# |    approx_kl            | 0.0072204806 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.321       |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 7.6          |
# |    n_updates            | 26800        |
# |    policy_gradient_loss | -0.00634     |
# |    value_loss           | 10.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 270         |
# |    time_elapsed         | 5514        |
# |    total_timesteps      | 552960      |
# | train/                  |             |
# |    approx_kl            | 0.007161568 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.315      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.95        |
# |    n_updates            | 26900       |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 6.81        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 271          |
# |    time_elapsed         | 5533         |
# |    total_timesteps      | 555008       |
# | train/                  |              |
# |    approx_kl            | 0.0032579708 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.269       |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.68         |
# |    n_updates            | 27000        |
# |    policy_gradient_loss | -0.00433     |
# |    value_loss           | 10.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 272         |
# |    time_elapsed         | 5553        |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.003830619 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.311      |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7           |
# |    n_updates            | 27100       |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 8.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 287         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 273         |
# |    time_elapsed         | 5574        |
# |    total_timesteps      | 559104      |
# | train/                  |             |
# |    approx_kl            | 0.010434391 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46.1        |
# |    n_updates            | 27200       |
# |    policy_gradient_loss | -0.00578    |
# |    value_loss           | 52          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 274         |
# |    time_elapsed         | 5594        |
# |    total_timesteps      | 561152      |
# | train/                  |             |
# |    approx_kl            | 0.006670758 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.86        |
# |    n_updates            | 27300       |
# |    policy_gradient_loss | -0.00696    |
# |    value_loss           | 15.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 275         |
# |    time_elapsed         | 5613        |
# |    total_timesteps      | 563200      |
# | train/                  |             |
# |    approx_kl            | 0.005706855 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.314      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.48        |
# |    n_updates            | 27400       |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 16.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 267         |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 276         |
# |    time_elapsed         | 5633        |
# |    total_timesteps      | 565248      |
# | train/                  |             |
# |    approx_kl            | 0.008645413 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.321      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.95        |
# |    n_updates            | 27500       |
# |    policy_gradient_loss | -0.00609    |
# |    value_loss           | 10.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 282        |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 277        |
# |    time_elapsed         | 5655       |
# |    total_timesteps      | 567296     |
# | train/                  |            |
# |    approx_kl            | 0.01860773 |
# |    clip_fraction        | 0.0779     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.365     |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 10.1       |
# |    n_updates            | 27600      |
# |    policy_gradient_loss | -0.0103    |
# |    value_loss           | 12.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 295         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 278         |
# |    time_elapsed         | 5676        |
# |    total_timesteps      | 569344      |
# | train/                  |             |
# |    approx_kl            | 0.005983927 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.3         |
# |    n_updates            | 27700       |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 9.24        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 299        |
# |    ep_rew_mean          | 259        |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 279        |
# |    time_elapsed         | 5696       |
# |    total_timesteps      | 571392     |
# | train/                  |            |
# |    approx_kl            | 0.03480994 |
# |    clip_fraction        | 0.075      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.639     |
# |    explained_variance   | 0.855      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 4.16       |
# |    n_updates            | 27800      |
# |    policy_gradient_loss | -0.00857   |
# |    value_loss           | 9.7        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 308          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 280          |
# |    time_elapsed         | 5717         |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0028792778 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 9.72         |
# |    n_updates            | 27900        |
# |    policy_gradient_loss | -0.00361     |
# |    value_loss           | 24.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 281         |
# |    time_elapsed         | 5737        |
# |    total_timesteps      | 575488      |
# | train/                  |             |
# |    approx_kl            | 0.013220236 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 47.2        |
# |    n_updates            | 28000       |
# |    policy_gradient_loss | -0.00856    |
# |    value_loss           | 21.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 304         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 282         |
# |    time_elapsed         | 5756        |
# |    total_timesteps      | 577536      |
# | train/                  |             |
# |    approx_kl            | 0.012353971 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.8        |
# |    n_updates            | 28100       |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 77.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 305         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 283         |
# |    time_elapsed         | 5777        |
# |    total_timesteps      | 579584      |
# | train/                  |             |
# |    approx_kl            | 0.007823577 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.319      |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.6         |
# |    n_updates            | 28200       |
# |    policy_gradient_loss | -0.00606    |
# |    value_loss           | 34.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 284         |
# |    time_elapsed         | 5796        |
# |    total_timesteps      | 581632      |
# | train/                  |             |
# |    approx_kl            | 0.005624328 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.285      |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 29.6        |
# |    n_updates            | 28300       |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 42.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 298         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 285         |
# |    time_elapsed         | 5816        |
# |    total_timesteps      | 583680      |
# | train/                  |             |
# |    approx_kl            | 0.004368787 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.21        |
# |    n_updates            | 28400       |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 14.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 298          |
# |    ep_rew_mean          | 260          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 286          |
# |    time_elapsed         | 5834         |
# |    total_timesteps      | 585728       |
# | train/                  |              |
# |    approx_kl            | 0.0053525195 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.302       |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 5.17         |
# |    n_updates            | 28500        |
# |    policy_gradient_loss | -0.0057      |
# |    value_loss           | 14.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 292          |
# |    ep_rew_mean          | 261          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 287          |
# |    time_elapsed         | 5855         |
# |    total_timesteps      | 587776       |
# | train/                  |              |
# |    approx_kl            | 0.0055949045 |
# |    clip_fraction        | 0.0632       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.01         |
# |    n_updates            | 28600        |
# |    policy_gradient_loss | -0.00694     |
# |    value_loss           | 8.82         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 303         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 288         |
# |    time_elapsed         | 5876        |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.018589817 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.327      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.53        |
# |    n_updates            | 28700       |
# |    policy_gradient_loss | -0.00978    |
# |    value_loss           | 5.95        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 318          |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 289          |
# |    time_elapsed         | 5897         |
# |    total_timesteps      | 591872       |
# | train/                  |              |
# |    approx_kl            | 0.0036716852 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.429       |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.11         |
# |    n_updates            | 28800        |
# |    policy_gradient_loss | -0.00638     |
# |    value_loss           | 15.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 324        |
# |    ep_rew_mean          | 257        |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 290        |
# |    time_elapsed         | 5917       |
# |    total_timesteps      | 593920     |
# | train/                  |            |
# |    approx_kl            | 0.00569178 |
# |    clip_fraction        | 0.0617     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.441     |
# |    explained_variance   | 0.799      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 6.76       |
# |    n_updates            | 28900      |
# |    policy_gradient_loss | -0.00716   |
# |    value_loss           | 26.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 339          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 291          |
# |    time_elapsed         | 5939         |
# |    total_timesteps      | 595968       |
# | train/                  |              |
# |    approx_kl            | 0.0037480907 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.37        |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.9          |
# |    n_updates            | 29000        |
# |    policy_gradient_loss | -0.00466     |
# |    value_loss           | 33.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 350          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 292          |
# |    time_elapsed         | 5959         |
# |    total_timesteps      | 598016       |
# | train/                  |              |
# |    approx_kl            | 0.0063626985 |
# |    clip_fraction        | 0.0809       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.925        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.07         |
# |    n_updates            | 29100        |
# |    policy_gradient_loss | -0.008       |
# |    value_loss           | 5.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 366          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 293          |
# |    time_elapsed         | 5980         |
# |    total_timesteps      | 600064       |
# | train/                  |              |
# |    approx_kl            | 0.0042546894 |
# |    clip_fraction        | 0.0413       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.87         |
# |    n_updates            | 29200        |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 23.6         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 370        |
# |    ep_rew_mean          | 252        |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 294        |
# |    time_elapsed         | 6001       |
# |    total_timesteps      | 602112     |
# | train/                  |            |
# |    approx_kl            | 0.00743178 |
# |    clip_fraction        | 0.0584     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.548     |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.991      |
# |    n_updates            | 29300      |
# |    policy_gradient_loss | -0.00519   |
# |    value_loss           | 7.78       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 351         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 295         |
# |    time_elapsed         | 6021        |
# |    total_timesteps      | 604160      |
# | train/                  |             |
# |    approx_kl            | 0.023761991 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.334      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.1        |
# |    n_updates            | 29400       |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 325         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 296         |
# |    time_elapsed         | 6040        |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.012030546 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.458      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.83        |
# |    n_updates            | 29500       |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 54.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 325         |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 297         |
# |    time_elapsed         | 6062        |
# |    total_timesteps      | 608256      |
# | train/                  |             |
# |    approx_kl            | 0.010152517 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.321      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.7        |
# |    n_updates            | 29600       |
# |    policy_gradient_loss | -0.00635    |
# |    value_loss           | 39.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 326          |
# |    ep_rew_mean          | 260          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 298          |
# |    time_elapsed         | 6081         |
# |    total_timesteps      | 610304       |
# | train/                  |              |
# |    approx_kl            | 0.0072443318 |
# |    clip_fraction        | 0.0884       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.36        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 20.8         |
# |    n_updates            | 29700        |
# |    policy_gradient_loss | -0.00705     |
# |    value_loss           | 62.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 260          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 299          |
# |    time_elapsed         | 6101         |
# |    total_timesteps      | 612352       |
# | train/                  |              |
# |    approx_kl            | 0.0067446306 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.07         |
# |    n_updates            | 29800        |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 10.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 330         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 300         |
# |    time_elapsed         | 6121        |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.004831397 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.92        |
# |    n_updates            | 29900       |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 9.17        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 330          |
# |    ep_rew_mean          | 259          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 301          |
# |    time_elapsed         | 6141         |
# |    total_timesteps      | 616448       |
# | train/                  |              |
# |    approx_kl            | 0.0049173366 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.333       |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 17.7         |
# |    n_updates            | 30000        |
# |    policy_gradient_loss | -0.00629     |
# |    value_loss           | 19.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 302         |
# |    time_elapsed         | 6161        |
# |    total_timesteps      | 618496      |
# | train/                  |             |
# |    approx_kl            | 0.006164169 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.307      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.8        |
# |    n_updates            | 30100       |
# |    policy_gradient_loss | -0.00563    |
# |    value_loss           | 24.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 345         |
# |    ep_rew_mean          | 257         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 303         |
# |    time_elapsed         | 6181        |
# |    total_timesteps      | 620544      |
# | train/                  |             |
# |    approx_kl            | 0.059271622 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.375      |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.91        |
# |    n_updates            | 30200       |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 19.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 349         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 304         |
# |    time_elapsed         | 6203        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.005135146 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.3        |
# |    n_updates            | 30300       |
# |    policy_gradient_loss | -0.00678    |
# |    value_loss           | 30          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 330        |
# |    ep_rew_mean          | 258        |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 305        |
# |    time_elapsed         | 6223       |
# |    total_timesteps      | 624640     |
# | train/                  |            |
# |    approx_kl            | 0.03196848 |
# |    clip_fraction        | 0.0911     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.355     |
# |    explained_variance   | 0.781      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 40.7       |
# |    n_updates            | 30400      |
# |    policy_gradient_loss | -0.00947   |
# |    value_loss           | 38.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# ...
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 472         |
# |    time_elapsed         | 9670        |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.006036363 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.236      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.41        |
# |    n_updates            | 47100       |
# |    policy_gradient_loss | -0.00642    |
# |    value_loss           | 8.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 473         |
# |    time_elapsed         | 9689        |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.007237592 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.43        |
# |    n_updates            | 47200       |
# |    policy_gradient_loss | -0.0089     |
# |    value_loss           | 8.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | 271         |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 474         |
# |    time_elapsed         | 9711        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.004305615 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.226      |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 12.6        |
# |    n_updates            | 47300       |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 12          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 251          |
# |    ep_rew_mean          | 273          |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 475          |
# |    time_elapsed         | 9731         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0031068418 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.19         |
# |    n_updates            | 47400        |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 4.85         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 476         |
# |    time_elapsed         | 9750        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.010288691 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.6         |
# |    n_updates            | 47500       |
# |    policy_gradient_loss | -0.00626    |
# |    value_loss           | 15.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 235          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 477          |
# |    time_elapsed         | 9770         |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0044531478 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.22        |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.92         |
# |    n_updates            | 47600        |
# |    policy_gradient_loss | -0.00433     |
# |    value_loss           | 7.33         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 478         |
# |    time_elapsed         | 9791        |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.008332558 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.226      |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.18        |
# |    n_updates            | 47700       |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 9.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 479          |
# |    time_elapsed         | 9810         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0058609974 |
# |    clip_fraction        | 0.0536       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.208       |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.58         |
# |    n_updates            | 47800        |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 8.8          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 480          |
# |    time_elapsed         | 9830         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0040708915 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.32         |
# |    n_updates            | 47900        |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 6.97         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 224          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 481          |
# |    time_elapsed         | 9849         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0044295425 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.206       |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.78         |
# |    n_updates            | 48000        |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 11.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 482         |
# |    time_elapsed         | 9870        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.010163398 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.244      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.81        |
# |    n_updates            | 48100       |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 6.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 483         |
# |    time_elapsed         | 9889        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.007800812 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.22       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.77        |
# |    n_updates            | 48200       |
# |    policy_gradient_loss | -0.00576    |
# |    value_loss           | 21.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 225          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 484          |
# |    time_elapsed         | 9908         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0056317262 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.94         |
# |    n_updates            | 48300        |
# |    policy_gradient_loss | -0.00494     |
# |    value_loss           | 7.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 217          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 485          |
# |    time_elapsed         | 9927         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0059944745 |
# |    clip_fraction        | 0.0644       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.2          |
# |    n_updates            | 48400        |
# |    policy_gradient_loss | -0.00566     |
# |    value_loss           | 6.98         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 214          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 486          |
# |    time_elapsed         | 9948         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0059081586 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.09         |
# |    n_updates            | 48500        |
# |    policy_gradient_loss | -0.00645     |
# |    value_loss           | 7.02         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 487         |
# |    time_elapsed         | 9968        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.005675004 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.238      |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.47        |
# |    n_updates            | 48600       |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 11.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 221          |
# |    ep_rew_mean          | 273          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 488          |
# |    time_elapsed         | 9988         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0060933325 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.368       |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.89         |
# |    n_updates            | 48700        |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 5.86         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 229          |
# |    ep_rew_mean          | 272          |
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 489          |
# |    time_elapsed         | 10010        |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0049061636 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.15         |
# |    n_updates            | 48800        |
# |    policy_gradient_loss | -0.00881     |
# |    value_loss           | 8.4          |
# ------------------------------------------
# Total training time: 10027.51 seconds

# %%
# save the model 
model_name = "lunar_lander_model"
model.save(model_name)

# %%
# Create a new environment for evaluation
eval_env = gym.make('LunarLander-v2')

# Evaluate the model 
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True )

# Print the results

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.9/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=271.98 +/- 17.65920921137455

# %%
#This was performed in google colab because there was an error installing box2d with pycharm.
